# %%
import pandas as pd

# %%
df = pd.read_csv('data/survey_results_public.csv')
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# ...

# %%
df.groupby('Country')['ConvertedCompYearly'].mean()
# Out:
# Country
# Afghanistan                             2.794748e+06
# Albania                                 4.499814e+04
# Algeria                                 1.446114e+04
# Andorra                                 8.928200e+04
# Angola                                  2.155680e+04
#                                             ...
# Venezuela, Bolivarian Republic of...    2.246505e+04
# Viet Nam                                1.995289e+04
# Yemen                                   5.628667e+03
# Zambia                                  1.991491e+04
# Zimbabwe                                1.141477e+04
# Name: ConvertedCompYearly, Length: 181, dtype: float64

# %%
filt = df['Country'] == 'Afghanistan'
df.loc[filt, 'ConvertedCompYearly'].value_counts()
# Out:
# 9792.0        1
# 4200.0        1
# 3108.0        1
# 5448.0        1
# 155496.0      1
# 51804.0       1
# 23964.0       1
# 15132.0       1
# 4668.0        1
# 100.0         1
# 30468516.0    1
# Name: ConvertedCompYearly, dtype: int64

# %%
df.shape
# Out:
# (83439, 48)

# %%
df.loc[filt, 'ConvertedCompYearly'].mean()
# Out:
# 2794748.0

# %%
filt2 = df['ConvertedCompYearly'] == 30468516.0
df.loc[filt2]
# Out:
#        ResponseId                      MainBranch          Employment  \
# 65399       65400  I am a developer by profession  Employed full-time
#
#            Country US_State UK_Country  \
# 65399  Afghanistan      NaN        NaN
#
#                                                EdLevel     Age1stCode  \
# 65399  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)  25 - 34 years
#
#                              LearnCode YearsCode  ...              Age  \
# 65399  Online Courses or Certification         7  ...  35-44 years old
#
#                                                   Gender Trans  \
# 65399  Man;Non-binary, genderqueer, or gender non-con...   Yes
#
#                                                Sexuality  \
# 65399  Bisexual;Prefer to self-describe:;Gay or Lesbi...
#
#                                                Ethnicity  \
# 65399  South Asian;Hispanic or Latino/a/x;Black or of...
#
#                                            Accessibility  \
# ...

# %%
df.drop(index = 65399, inplace = True)
#already dropped
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [39], line 1
# ----> 1 df.drop(index = 65399, inplace = True)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:5391, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5243 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
# ...

# %%
df.shape
# Out:
# (83438, 48)

# %%
df.loc[filt, 'ConvertedCompYearly'].value_counts()
# Out:
# 9792.0      1
# 4200.0      1
# 3108.0      1
# 5448.0      1
# 155496.0    1
# 51804.0     1
# 23964.0     1
# 15132.0     1
# 4668.0      1
# 100.0       1
# Name: ConvertedCompYearly, dtype: int64

# %%
df.loc[filt, 'ConvertedCompYearly'].mean()
# Out:
# 27371.2

# %%
average_salaries = df.groupby('Country')['ConvertedCompYearly'].describe()

# %%
average_salaries.groupby('')
# Out:
#                                       count          mean            std  \
# Country
# Afghanistan                            10.0  27371.200000   47549.680585
# Albania                                35.0  44998.142857  115981.347833
# Algeria                                14.0  14461.142857   14293.693385
# Andorra                                 4.0  89282.000000   53445.558113
# Angola                                 10.0  21556.800000   29800.824257
# ...                                     ...           ...            ...
# Venezuela, Bolivarian Republic of...   62.0  22465.048387   36350.098079
# Viet Nam                              148.0  19952.885135   29680.385533
# Yemen                                   6.0   5628.666667    6860.341877
# Zambia                                 11.0  19914.909091   29354.286697
# Zimbabwe                               13.0  11414.769231   10534.865085
#
#                                           min       25%      50%        75%  \
# ...
